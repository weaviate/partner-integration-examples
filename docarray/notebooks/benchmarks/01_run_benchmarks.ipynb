# %%
# %cd /workspaces/docarray/docarray/scripts
# Out:
# /workspaces/docarray/docarray/scripts

# %%
# !wget http://ann-benchmarks.com/sift-128-euclidean.hdf5
# Out:
# --2023-01-17 15:18:09--  http://ann-benchmarks.com/sift-128-euclidean.hdf5
# Resolving ann-benchmarks.com (ann-benchmarks.com)... 52.217.0.155, 52.217.169.109, 52.216.93.114, ...
# Connecting to ann-benchmarks.com (ann-benchmarks.com)|52.217.0.155|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 525128288 (501M) [binary/octet-stream]
# Saving to: ‘sift-128-euclidean.hdf5.1’
#
# sift-128-euclidean. 100%[===================>] 500.80M  48.4MB/s    in 9.7s
#
# 2023-01-17 15:18:19 (51.6 MB/s) - ‘sift-128-euclidean.hdf5.1’ saved [525128288/525128288]

# %%
# !python benchmarking_sift1m.py --exclude-backends \
    memory,sqlite,annlite,elasticsearch,redis
# Out:
# Reading dataset
# sudo: docker-compose: command not found
#
# Backend: Qdrant
# Backend hnsw config {'m': 16, 'ef_construct': 64, 'hnsw_ef': 32}
# Storage Backend qdrant failed: <_InactiveRpcError of RPC that terminated with:
#         status = StatusCode.UNAVAILABLE
#         details = "failed to connect to all addresses"
#         debug_error_string =
# "{"created":"@1673968851.705610079","description":"Failed to pick
# subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file
# _line":3260,"referenced_errors":[{"created":"@1673968851.705609369","description
# ":"failed to connect to all
# addresses","file":"src/core/lib/transport/error_utils.cc","file_line":167,"grpc_
# status":14}]}"
# >
# sudo: docker-compose: command not found
#
# Backend: Qdrant
# Backend hnsw config {'m': 16, 'ef_construct': 64, 'hnsw_ef': 64}
# Storage Backend qdrant failed: <_InactiveRpcError of RPC that terminated with:
#         status = StatusCode.UNAVAILABLE
# ...
